# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_parquet('./data/test_dataset/ch2024_test_m_activity.parquet.gzip')

# %%
import datetime

# %%
df
# Out:
#         subject_id               timestamp m_activity
# 0                5 2023-11-05 00:00:39.044          3
# 1                5 2023-11-05 00:01:39.044          3
# 2                5 2023-11-05 00:02:39.044          3
# 3                5 2023-11-05 00:03:39.043          3
# 4                5 2023-11-05 00:04:39.044          3
# ...            ...                     ...        ...
# 165063           8 2023-11-09 23:55:27.604          3
# 165064           8 2023-11-09 23:56:27.604          3
# 165065           8 2023-11-09 23:57:27.604          3
# 165066           8 2023-11-09 23:58:27.604          3
# 165067           8 2023-11-09 23:59:27.604          3
#
# [165068 rows x 3 columns]

# %%
df = pd.read_csv("./data/user01-06/user01/1598759880/1598759880_label.csv")

# %%
df
# Out:
#                ts action  actionOption    actionSub  actionSubOption  \
# 0    1.598760e+09   work           212          NaN              NaN
# 1    1.598760e+09   work           212          NaN              NaN
# 2    1.598760e+09   work           212          NaN              NaN
# 3    1.598760e+09   work           212          NaN              NaN
# 4    1.598760e+09   work           212          NaN              NaN
# ..            ...    ...           ...          ...              ...
# 459  1.598796e+09   meal           121  meal_amount              2.0
# 460  1.598796e+09   meal           121  meal_amount              2.0
# 461  1.598796e+09   meal           121  meal_amount              2.0
# 462  1.598796e+09   meal           121  meal_amount              2.0
# 463  1.598796e+09   meal           121  meal_amount              2.0
#
#      condition  conditionSub1Option  conditionSub2Option         place  \
# ...

# %%
df["ts"] = pd.to_datetime(df["ts"], unit='s')

# %%
df
# Out:
#                      ts action  actionOption    actionSub  actionSubOption  \
# 0   2020-08-30 03:58:00   work           212          NaN              NaN
# 1   2020-08-30 03:59:00   work           212          NaN              NaN
# 2   2020-08-30 04:00:00   work           212          NaN              NaN
# 3   2020-08-30 04:01:00   work           212          NaN              NaN
# 4   2020-08-30 04:02:00   work           212          NaN              NaN
# ..                  ...    ...           ...          ...              ...
# 459 2020-08-30 13:55:00   meal           121  meal_amount              2.0
# 460 2020-08-30 13:56:00   meal           121  meal_amount              2.0
# 461 2020-08-30 13:57:00   meal           121  meal_amount              2.0
# 462 2020-08-30 13:58:00   meal           121  meal_amount              2.0
# 463 2020-08-30 13:59:00   meal           121  meal_amount              2.0
#
# ...

# %%
df = pd.read_csv("./data/user_sleep_2020.csv")

# %%
df
# Out:
#      userId    timezone        date     startDt       endDt  lastUpdate  \
# 0    user24  Asia/Seoul  2020-08-30  1598708760  1598740860  1598748252
# 1    user24  Asia/Seoul  2020-08-31  1598800140  1598825940  1598833333
# 2    user24  Asia/Seoul  2020-09-01  1598885940  1598908800  1598916190
# 3    user24  Asia/Seoul  2020-09-02  1598979420  1598999580  1599006969
# 4    user24  Asia/Seoul  2020-09-03  1599060780  1599085980  1599093370
# ..      ...         ...         ...         ...         ...         ...
# 610  user06  Asia/Seoul  2020-10-05  1601831040  1601861820  1601862001
# 611  user06  Asia/Seoul  2020-10-06  1601923560  1601951220  1601951380
# 612  user06  Asia/Seoul  2020-10-07  1602001320  1602023760  1602031150
# 613  user06  Asia/Seoul  2020-10-08  1602091020  1602110280  1602117673
# 614  user06  Asia/Seoul  2020-10-09  1602183900  1602220140  1602227533
#
#      wakeupduration  lightsleepduration  deepsleepduration  wakeupcount  ...  \
# ...

# %%
dts = df['durationtosleep']
dts
# Out:
# 0       1740
# 1       3180
# 2       1440
# 3       1380
# 4       1680
#        ...
# 610     7740
# 611     1320
# 612    10440
# 613     2820
# 614     3000
# Name: durationtosleep, Length: 615, dtype: int64

# %%
avg = np.average(dts)
avg
# Out:
# 1916.6829268292684

# %%
df["SOL"] = df['durationtosleep'].apply(lambda x : 0 if x > 1800 else 1)

# %%
df
# Out:
#      userId    timezone        date     startDt       endDt  lastUpdate  \
# 0    user24  Asia/Seoul  2020-08-30  1598708760  1598740860  1598748252
# 1    user24  Asia/Seoul  2020-08-31  1598800140  1598825940  1598833333
# 2    user24  Asia/Seoul  2020-09-01  1598885940  1598908800  1598916190
# 3    user24  Asia/Seoul  2020-09-02  1598979420  1598999580  1599006969
# 4    user24  Asia/Seoul  2020-09-03  1599060780  1599085980  1599093370
# ..      ...         ...         ...         ...         ...         ...
# 610  user06  Asia/Seoul  2020-10-05  1601831040  1601861820  1601862001
# 611  user06  Asia/Seoul  2020-10-06  1601923560  1601951220  1601951380
# 612  user06  Asia/Seoul  2020-10-07  1602001320  1602023760  1602031150
# 613  user06  Asia/Seoul  2020-10-08  1602091020  1602110280  1602117673
# 614  user06  Asia/Seoul  2020-10-09  1602183900  1602220140  1602227533
#
#      wakeupduration  lightsleepduration  deepsleepduration  wakeupcount  ...  \
# ...

# %%
df[['userId', 'date', 'SOL']].head(50)
# Out:
#     userId        date  SOL
# 0   user24  2020-08-30    1
# 1   user24  2020-08-31    0
# 2   user24  2020-09-01    1
# 3   user24  2020-09-02    1
# 4   user24  2020-09-03    1
# 5   user24  2020-09-04    1
# 6   user24  2020-09-05    0
# 7   user24  2020-09-06    1
# 8   user24  2020-09-07    1
# 9   user24  2020-09-08    1
# 10  user24  2020-09-09    0
# 11  user24  2020-09-10    1
# 12  user24  2020-09-11    0
# 13  user24  2020-09-12    0
# 14  user24  2020-09-13    0
# 15  user24  2020-09-14    1
# 16  user24  2020-09-15    0
# 17  user24  2020-09-16    0
# 18  user24  2020-09-17    1
# 19  user24  2020-09-18    1
# 20  user24  2020-09-19    1
# 21  user24  2020-09-20    1
# 22  user24  2020-09-21    0
# 23  user24  2020-09-22    0
# 24  user24  2020-09-23    1
# 25  user24  2020-09-24    0
# 26  user24  2020-09-24    1
# 27  user24  2020-09-25    1
# 28  user24  2020-09-26    1
# 29  user24  2020-09-27    1
# 30  user24  2020-09-28    0
# 31  user23  2020-08-31    1
# ...
